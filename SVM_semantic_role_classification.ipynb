# %% [markdown]
# # Thai Semantic Role Classification Using SVM

# %%
DATA_PATH='./'
RAW_PATH = f'{DATA_PATH}raw/'
MODEL_PATH = f'{DATA_PATH}svm/'
W_MODEL_PATH = f'{DATA_PATH}model/thai2fit/'
# MODEL_NAME = "svm_model_prev.sav"
# TRAIN_PATH = f'{RAW_PATH}train.data'
# VALIDATION_PATH = f'{RAW_PATH}val.data'

# %%
# !wget -O $W_MODEL_PATH/thai2vecNoSym.bin  https://raw.githubusercontent.com/SuphanutN/Thai-NER-BiLSTMCRF-WordCharEmbedding/master/model/thai2fit/thai2vecNoSym.bin

# %%
# !python sem_role_svc.py --train_data=$TRAIN_PATH --validation_data=$VALIDATION_PATH --model_path=$MODEL_PATH --model_name=$MODEL_NAME --w_model_path=$W_MODEL_PATH

# %%
runs = {f'f{i}':f'_cv{i}' for i in range(5)}
runs.update({'oov':'_oov', 'one':''})
runs_param = [(f'train{v}.data', f'val{v}.data', f'svm_model_{k}.sav') for k, v in runs.items()]

# %%
for train_name, val_name, model_name in runs_param:
    TRAIN_PATH = f'{RAW_PATH}{train_name}'
    VALIDATION_PATH = f'{RAW_PATH}{val_name}'
    MODEL_NAME = model_name
    # !python sem_role_svc.py --train_data=$TRAIN_PATH --validation_data=$VALIDATION_PATH --model_path=$MODEL_PATH --model_name=$MODEL_NAME --w_model_path=$W_MODEL_PATH
# Out:
# =====================================
# TRAIN_PATH 		=  ./raw/train_cv0.data
# VALIDATION_PATH 	=  ./raw/val_cv0.data
# MODEL_PATH 		=  ./svm/
# MODEL_NAME 		=  svm_model_f0.sav
# Word_Embed__MODEL_PATH 	=  ./model/thai2fit/
# Dict_MODEL_PATH 	=  ./svm//dictionary/
# =====================================
# Train sentences =  1790
# Test sentences  =  448
# Sample sentence :  [('ทำให้', 'Verb'), ('เกิด', 'Verb'), ('โรค', 'Object'), ('รากเน่า', 'Object'), ('ได้', 'Z-O'), ('_', 'Z-O')]
#
# Load Thai2Fit model completed ...
#
# No. of unique words :  2235
# No. of tags :  12
# No. of known words :  55677
# Semantic role tag :  {'Accompanyment': 0, 'Agent': 1, 'Benefactor': 2, 'Experiencer': 3, 'Instrument': 4, 'Location': 5, 'Manner': 6, 'Measure': 7, 'Object': 8, 'Time': 9, 'Verb': 10, 'Z-O': 11}
#
# Save Dictionary for Semantic Role Tag completed ...
#
# Size of X_train :  (17568, 800)
# Size of y_train :  (17568,)
# Prepare Training Dataset completed ...
#
# No. of y_test :  448
# No. of y_test :  448
# Prepare Testing Dataset completed ...
#
#
# Trained Model exists, Load model from ./svm/svm_model_f0.sav.
# Load Trained Model from ./svm/svm_model_f0.sav completed ...
#
#
# Prediction of validation data started ...
#
# Prediction of validation data completed ...
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
# Accompanyment     0.4074    0.1447    0.2136        76
#         Agent     0.3958    0.1250    0.1900       152
#    Benefactor     0.0000    0.0000    0.0000         9
#   Experiencer     0.4500    0.0776    0.1324       116
#    Instrument     1.0000    0.0625    0.1176        16
#      Location     0.4457    0.2611    0.3293       157
#        Manner     0.8667    0.1529    0.2600        85
#       Measure     0.5436    0.5551    0.5493       236
#        Object     0.5833    0.5973    0.5902       961
#          Time     0.6000    0.4314    0.5019       153
#
#     micro avg     0.5624    0.4411    0.4944      1961
#     macro avg     0.5292    0.2408    0.2884      1961
#  weighted avg     0.5526    0.4411    0.4639      1961
#   samples avg     0.1858    0.1858    0.1858      1961
#
# =====================================
# TRAIN_PATH 		=  ./raw/train_cv1.data
# VALIDATION_PATH 	=  ./raw/val_cv1.data
# MODEL_PATH 		=  ./svm/
# MODEL_NAME 		=  svm_model_f1.sav
# Word_Embed__MODEL_PATH 	=  ./model/thai2fit/
# Dict_MODEL_PATH 	=  ./svm//dictionary/
# =====================================
# Train sentences =  1790
# Test sentences  =  448
# Sample sentence :  [('ทำให้', 'Verb'), ('เกิด', 'Verb'), ('รา', 'Object'), ('อื่น', 'Object'), ('ที่', 'Object'), ('ไม่', 'Object'), ('ต้องการ', 'Object'), ('จน', 'Z-O'), ('กระทบ', 'Z-O'), ('กับ', 'Object'), ('ผลผลิต', 'Object'), ('_', 'Z-O')]
#
# Load Thai2Fit model completed ...
#
# No. of unique words :  2276
# No. of tags :  12
# No. of known words :  55677
# Semantic role tag :  {'Accompanyment': 0, 'Agent': 1, 'Benefactor': 2, 'Experiencer': 3, 'Instrument': 4, 'Location': 5, 'Manner': 6, 'Measure': 7, 'Object': 8, 'Time': 9, 'Verb': 10, 'Z-O': 11}
#
# Save Dictionary for Semantic Role Tag completed ...
#
# Size of X_train :  (18087, 800)
# Size of y_train :  (18087,)
# Prepare Training Dataset completed ...
#
# No. of y_test :  448
# No. of y_test :  448
# Prepare Testing Dataset completed ...
#
#
# Trained Model exists, Load model from ./svm/svm_model_f1.sav.
# Load Trained Model from ./svm/svm_model_f1.sav completed ...
#
#
# Prediction of validation data started ...
#
# Prediction of validation data completed ...
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
# Accompanyment     1.0000    0.0851    0.1569        47
#         Agent     0.7778    0.2079    0.3281       101
#    Benefactor     0.0000    0.0000    0.0000         6
#   Experiencer     0.4211    0.0661    0.1143       121
#    Instrument     1.0000    0.0286    0.0556        35
#      Location     0.7403    0.3000    0.4270       190
#        Manner     0.7273    0.1143    0.1975        70
#       Measure     0.4254    0.5461    0.4783       141
#        Object     0.5784    0.6826    0.6262       816
#          Time     0.6329    0.3704    0.4673       135
#
#     micro avg     0.5749    0.4711    0.5179      1662
#     macro avg     0.6303    0.2401    0.2851      1662
#  weighted avg     0.6140    0.4711    0.4770      1662
#   samples avg     0.1893    0.1893    0.1893      1662
#
# =====================================
# TRAIN_PATH 		=  ./raw/train_cv2.data
# VALIDATION_PATH 	=  ./raw/val_cv2.data
# MODEL_PATH 		=  ./svm/
# MODEL_NAME 		=  svm_model_f2.sav
# Word_Embed__MODEL_PATH 	=  ./model/thai2fit/
# Dict_MODEL_PATH 	=  ./svm//dictionary/
# =====================================
# Train sentences =  1790
# Test sentences  =  448
# Sample sentence :  [('ให้', 'Verb'), ('หา', 'Verb'), ('กิน', 'Verb'), ('หญ้า', 'Object'), ('และ', 'Object'), ('ใบ', 'Object'), ('ไผ่', 'Object'), ('_', 'Z-O'), ('ใน', 'Time'), ('ช่วง', 'Time'), ('กลางวัน', 'Time')]
#
# Load Thai2Fit model completed ...
#
# No. of unique words :  2307
# No. of tags :  12
# No. of known words :  55677
# Semantic role tag :  {'Accompanyment': 0, 'Agent': 1, 'Benefactor': 2, 'Experiencer': 3, 'Instrument': 4, 'Location': 5, 'Manner': 6, 'Measure': 7, 'Object': 8, 'Time': 9, 'Verb': 10, 'Z-O': 11}
#
# Save Dictionary for Semantic Role Tag completed ...
#
# Size of X_train :  (17786, 800)
# Size of y_train :  (17786,)
# Prepare Training Dataset completed ...
#
# No. of y_test :  448
# No. of y_test :  448
# Prepare Testing Dataset completed ...
#
#
# Trained Model exists, Load model from ./svm/svm_model_f2.sav.
# Load Trained Model from ./svm/svm_model_f2.sav completed ...
#
#
# Prediction of validation data started ...
#
# Prediction of validation data completed ...
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
# Accompanyment     0.5556    0.2273    0.3226        44
#         Agent     0.6944    0.1437    0.2381       174
#    Benefactor     0.0000    0.0000    0.0000         6
#   Experiencer     0.5000    0.0729    0.1273        96
#    Instrument     0.5000    0.0250    0.0476        40
#      Location     0.4808    0.3401    0.3984       147
#        Manner     0.6250    0.0820    0.1449        61
#       Measure     0.5837    0.5837    0.5837       233
#        Object     0.5843    0.5753    0.5798       916
#          Time     0.5000    0.3676    0.4237       136
#
#     micro avg     0.5723    0.4377    0.4960      1853
#     macro avg     0.5024    0.2418    0.2866      1853
#  weighted avg     0.5727    0.4377    0.4651      1853
#   samples avg     0.1827    0.1827    0.1827      1853
#
# =====================================
# TRAIN_PATH 		=  ./raw/train_cv3.data
# VALIDATION_PATH 	=  ./raw/val_cv3.data
# MODEL_PATH 		=  ./svm/
# MODEL_NAME 		=  svm_model_f3.sav
# Word_Embed__MODEL_PATH 	=  ./model/thai2fit/
# Dict_MODEL_PATH 	=  ./svm//dictionary/
# =====================================
# Train sentences =  1791
# Test sentences  =  447
# Sample sentence :  [('จน', 'Z-O'), ('จะ', 'Z-O'), ('ทำให้', 'Verb'), ('เกิด', 'Verb'), ('การ', 'Object'), ('ตกค้าง', 'Object'), ('หรือ', 'Object'), ('ปนเปื้อน', 'Object'), ('ใน', 'Object'), ('ผลผลิต', 'Object'), ('ได้', 'Z-O')]
#
# Load Thai2Fit model completed ...
#
# No. of unique words :  2250
# No. of tags :  12
# No. of known words :  55677
# Semantic role tag :  {'Accompanyment': 0, 'Agent': 1, 'Benefactor': 2, 'Experiencer': 3, 'Instrument': 4, 'Location': 5, 'Manner': 6, 'Measure': 7, 'Object': 8, 'Time': 9, 'Verb': 10, 'Z-O': 11}
#
# Save Dictionary for Semantic Role Tag completed ...
#
# Size of X_train :  (17820, 800)
# Size of y_train :  (17820,)
# Prepare Training Dataset completed ...
#
# No. of y_test :  447
# No. of y_test :  447
# Prepare Testing Dataset completed ...
#
#
# Trained Model exists, Load model from ./svm/svm_model_f3.sav.
# Load Trained Model from ./svm/svm_model_f3.sav completed ...
#
#
# Prediction of validation data started ...
#
# Prediction of validation data completed ...
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
# Accompanyment     0.3333    0.2917    0.3111        24
#         Agent     0.4444    0.1266    0.1970       158
#    Benefactor     0.0000    0.0000    0.0000         9
#   Experiencer     0.3000    0.0229    0.0426       131
#    Instrument     0.5000    0.0385    0.0714        26
#      Location     0.5573    0.3202    0.4067       228
#        Manner     1.0000    0.0328    0.0635        61
#       Measure     0.4895    0.5879    0.5342       199
#        Object     0.5608    0.5763    0.5685       904
#          Time     0.6456    0.3446    0.4493       148
#
#     micro avg     0.5453    0.4211    0.4752      1888
#     macro avg     0.4831    0.2341    0.2644      1888
#  weighted avg     0.5395    0.4211    0.4393      1888
#   samples avg     0.1805    0.1805    0.1805      1888
#
# =====================================
# TRAIN_PATH 		=  ./raw/train_cv4.data
# VALIDATION_PATH 	=  ./raw/val_cv4.data
# MODEL_PATH 		=  ./svm/
# MODEL_NAME 		=  svm_model_f4.sav
# Word_Embed__MODEL_PATH 	=  ./model/thai2fit/
# Dict_MODEL_PATH 	=  ./svm//dictionary/
# =====================================
# Train sentences =  1791
# Test sentences  =  447
# Sample sentence :  [('โรค', 'Object'), ('นี้', 'Object'), ('มัก', 'Z-O'), ('เกิด', 'Verb'), ('กับ', 'Location'), ('สุกร', 'Location'), ('รุ่น', 'Location'), ('_', 'Location'), ('สุกร', 'Location'), ('ขุน', 'Location'), ('_', 'Location'), ('และ', 'Location'), ('สุกร', 'Location'), ('พันธ์', 'Location'), ('ทดแทน', 'Location')]
#
# Load Thai2Fit model completed ...
#
# No. of unique words :  2242
# No. of tags :  12
# No. of known words :  55677
# Semantic role tag :  {'Accompanyment': 0, 'Agent': 1, 'Benefactor': 2, 'Experiencer': 3, 'Instrument': 4, 'Location': 5, 'Manner': 6, 'Measure': 7, 'Object': 8, 'Time': 9, 'Verb': 10, 'Z-O': 11}
#
# Save Dictionary for Semantic Role Tag completed ...
#
# Size of X_train :  (17635, 800)
# Size of y_train :  (17635,)
# Prepare Training Dataset completed ...
#
# No. of y_test :  447
# No. of y_test :  447
# Prepare Testing Dataset completed ...
#
#
# Trained Model exists, Load model from ./svm/svm_model_f4.sav.
# Load Trained Model from ./svm/svm_model_f4.sav completed ...
#
#
# Prediction of validation data started ...
#
# Prediction of validation data completed ...
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
# Accompanyment     0.4643    0.2281    0.3059        57
#         Agent     0.5357    0.2222    0.3141       135
#    Benefactor     0.5000    0.5000    0.5000         2
#   Experiencer     0.5333    0.0559    0.1013       143
#    Instrument     0.1667    0.0455    0.0714        22
#      Location     0.5128    0.1835    0.2703       218
#        Manner     0.7000    0.1167    0.2000        60
#       Measure     0.5234    0.5726    0.5469       234
#        Object     0.5619    0.6166    0.5880       913
#          Time     0.5825    0.4082    0.4800       147
#
#     micro avg     0.5508    0.4438    0.4915      1931
#     macro avg     0.5081    0.2949    0.3378      1931
#  weighted avg     0.5462    0.4438    0.4574      1931
#   samples avg     0.1868    0.1868    0.1868      1931
#
# =====================================
# TRAIN_PATH 		=  ./raw/train_oov.data
# VALIDATION_PATH 	=  ./raw/val_oov.data
# MODEL_PATH 		=  ./svm/
# MODEL_NAME 		=  svm_model_oov.sav
# Word_Embed__MODEL_PATH 	=  ./model/thai2fit/
# Dict_MODEL_PATH 	=  ./svm//dictionary/
# =====================================
# Train sentences =  1807
# Test sentences  =  431
# Sample sentence :  [('เกิด', 'Verb'), ('ก๊าซ', 'Object'), ('คาร์บอนไดออกไซด์', 'Object'), ('และ', 'Object'), ('แอมโมเนีย', 'Object'), ('ที่', 'Object'), ('เป็น', 'Object'), ('พิษ', 'Object'), ('ต่อ', 'Object'), ('ปลา', 'Object')]
#
# Load Thai2Fit model completed ...
#
# No. of unique words :  2241
# No. of tags :  12
# No. of known words :  55677
# Semantic role tag :  {'Accompanyment': 0, 'Agent': 1, 'Benefactor': 2, 'Experiencer': 3, 'Instrument': 4, 'Location': 5, 'Manner': 6, 'Measure': 7, 'Object': 8, 'Time': 9, 'Verb': 10, 'Z-O': 11}
#
# Save Dictionary for Semantic Role Tag completed ...
#
# Size of X_train :  (17987, 800)
# Size of y_train :  (17987,)
# Prepare Training Dataset completed ...
#
# No. of y_test :  431
# No. of y_test :  431
# Prepare Testing Dataset completed ...
#
#
# Trained Model exists, Load model from ./svm/svm_model_oov.sav.
# Load Trained Model from ./svm/svm_model_oov.sav completed ...
#
#
# Prediction of validation data started ...
#
# Prediction of validation data completed ...
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
# Accompanyment     1.0000    0.1818    0.3077        77
#         Agent     0.2500    0.0973    0.1401       113
#    Benefactor     0.0000    0.0000    0.0000         8
#   Experiencer     0.5000    0.0667    0.1176        75
#    Instrument     0.0000    0.0000    0.0000        21
#      Location     0.6167    0.1616    0.2561       229
#        Manner     0.0000    0.0000    0.0000       102
#       Measure     0.4286    0.5556    0.4839       162
#        Object     0.5967    0.6007    0.5987       904
#          Time     0.4660    0.3721    0.4138       129
#
#     micro avg     0.5528    0.4110    0.4715      1820
#     macro avg     0.3858    0.2036    0.2318      1820
#  weighted avg     0.5236    0.4110    0.4285      1820
#   samples avg     0.1765    0.1765    0.1765      1820
#
# =====================================
# TRAIN_PATH 		=  ./raw/train.data
# VALIDATION_PATH 	=  ./raw/val.data
# MODEL_PATH 		=  ./svm/
# MODEL_NAME 		=  svm_model_one.sav
# Word_Embed__MODEL_PATH 	=  ./model/thai2fit/
# Dict_MODEL_PATH 	=  ./svm//dictionary/
# =====================================
# Train sentences =  1790
# Test sentences  =  448
# Sample sentence :  [('เกษตรกร', 'Agent'), ('ที่', 'Z-O'), ('เข้า', 'Z-O'), ('มา', 'Z-O'), ('รับ', 'Z-O'), ('การ', 'Z-O'), ('อบรม', 'Verb')]
#
# Load Thai2Fit model completed ...
#
# No. of unique words :  2235
# No. of tags :  12
# No. of known words :  55677
# Semantic role tag :  {'Accompanyment': 0, 'Agent': 1, 'Benefactor': 2, 'Experiencer': 3, 'Instrument': 4, 'Location': 5, 'Manner': 6, 'Measure': 7, 'Object': 8, 'Time': 9, 'Verb': 10, 'Z-O': 11}
#
# Save Dictionary for Semantic Role Tag completed ...
#
# Size of X_train :  (17568, 800)
# Size of y_train :  (17568,)
# Prepare Training Dataset completed ...
#
# No. of y_test :  448
# No. of y_test :  448
# Prepare Testing Dataset completed ...
#
#
# Trained Model exists, Load model from ./svm/svm_model_one.sav.
# Load Trained Model from ./svm/svm_model_one.sav completed ...
#
#
# Prediction of validation data started ...
#
# Prediction of validation data completed ...
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/tf1/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
# Accompanyment     0.4074    0.1447    0.2136        76
#         Agent     0.3958    0.1250    0.1900       152
#    Benefactor     0.0000    0.0000    0.0000         9
#   Experiencer     0.4500    0.0776    0.1324       116
#    Instrument     1.0000    0.0625    0.1176        16
#      Location     0.4457    0.2611    0.3293       157
#        Manner     0.8667    0.1529    0.2600        85
#       Measure     0.5436    0.5551    0.5493       236
#        Object     0.5833    0.5973    0.5902       961
#          Time     0.6000    0.4314    0.5019       153
#
#     micro avg     0.5624    0.4411    0.4944      1961
#     macro avg     0.5292    0.2408    0.2884      1961
#  weighted avg     0.5526    0.4411    0.4639      1961
#   samples avg     0.1858    0.1858    0.1858      1961
