# %% [markdown]
# # ทำ Semantic Role Classification ภาษาไทย โดยใช้ Transformers Model จาก Hugging Face
#
# สร้าง Custom Dataset Loading Script
# - https://mageswaran1989.medium.com/how-to-build-custom-ner-huggingface-dataset-for-receipts-and-train-with-huggingface-transformers-6c954b84473c
# - https://huggingface.co/docs/datasets/dataset_script.html#download-data-files-and-organize-splits
#
# การใช้ Transformers Model จาก Hugging Face
# - https://medium.com/super-ai-engineer/ทำ-ner-ภาษาไทย-โดยใช้-transformers-model-จาก-huggingface-130c7a201d5e

# %%
MODEL_PATH = f'./wangchan/'
# MODEL_NAME = "semrole_wangchan"
# CONFIG_NAME = 'std'

# %%
# %run sem_role_wangchan.py --config_name=oov --model_path=$MODEL_PATH --model_name=wangchan_oov

# %%
# %run sem_role_wangchan.py --config_name=std --model_path=$MODEL_PATH --model_name=wangchan_std

# %%
for CONFIG_NAME in ['cv0', 'cv1', 'cv2', 'cv3', 'cv4', 'oov' ,'std']:
    MODEL_NAME = f"wangchan_{CONFIG_NAME}"
    # %run sem_role_wangchan.py --config_name=$CONFIG_NAME --model_path=$MODEL_PATH --model_name=$MODEL_NAME
# Out:
# 2022-02-09 14:32:22.796517: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Reusing dataset sem_role_bank (/home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv0/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504)
# Hugging Face Transformers Version : 4.15.0
# Hugging Face Tokenizers Version : 0.10.3
# =====================================
# CONFIG_NAME 		=  cv0
# MODEL_PATH 		=  ./wangchan/
# MODEL_NAME 		=  wangchan_cv0
# =========  Hyperparameters  =========
# model_checkpoint 	=  airesearch/wangchanberta-base-att-spm-uncased
# batch_size 		=  4
# =====================================
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset :  DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 1790
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 448
#     })
# })
# Sample  :  ['เลี้ยง', 'ต่อไป', 'จนกระทั่ง', 'ปลา', 'สามารถ', 'กิน', 'ลูกน้ำ', 'ได้']
# Label List :  ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time', 'Verb', 'Z-O']
#
# Tokenization started ...
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv0/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-efd44adbb97e8c1e.arrow
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv0/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-7eedb8abc665a48e.arrow
# Tokenization completed ...
#
#
# Trained Model exists, Load model from ./wangchan/wangchan_cv0.
# Load Trained Model from ./wangchan/wangchan_cv0 completed ...
# The following columns in the test set  don't have a corresponding argument in `CamembertForTokenClassification.forward` and have been ignored: tokens, role_tags, id.
# ***** Running Prediction *****
#   Num examples = 448
#   Batch size = 4
# Prediction of validation data started ...
#     <div>
#
#       <progress value='112' max='112' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [112/112 00:01]
#     </div>
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Z-O seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Agent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Verb seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Object seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Manner seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Experiencer seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Time seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Measure seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Benefactor seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Location seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Accompanyment seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Instrument seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# Prediction of validation data completed ...
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Reusing dataset sem_role_bank (/home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv1/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504)
# {'O': {'precision': 0.3800995024875622, 'recall': 0.4619105199516324, 'f1': 0.41703056768558955, 'number': 827}, 'anner': {'precision': 0.13333333333333333, 'recall': 0.08, 'f1': 0.1, 'number': 25}, 'ccompanyment': {'precision': 0.09090909090909091, 'recall': 0.2222222222222222, 'f1': 0.1290322580645161, 'number': 9}, 'easure': {'precision': 0.2608695652173913, 'recall': 0.375, 'f1': 0.30769230769230765, 'number': 48}, 'enefactor': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 16}, 'erb': {'precision': 0.6247544204322201, 'recall': 0.70509977827051, 'f1': 0.6625000000000001, 'number': 451}, 'gent': {'precision': 0.39080459770114945, 'recall': 0.4358974358974359, 'f1': 0.41212121212121217, 'number': 78}, 'ime': {'precision': 0.17647058823529413, 'recall': 0.26666666666666666, 'f1': 0.21238938053097345, 'number': 45}, 'nstrument': {'precision': 0.25, 'recall': 0.125, 'f1': 0.16666666666666666, 'number': 8}, 'ocation': {'precision': 0.27956989247311825, 'recall': 0.35135135135135137, 'f1': 0.31137724550898205, 'number': 74}, 'xperiencer': {'precision': 0.48148148148148145, 'recall': 0.41767068273092367, 'f1': 0.4473118279569892, 'number': 249}, 'overall_precision': 0.4299378287900526, 'overall_recall': 0.4912568306010929, 'overall_f1': 0.4585564906911502, 'overall_accuracy': 0.7070948639107163}
# Align labels to original tokens ...
#
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
#                precision    recall  f1-score   support
#
# Accompanyment     0.6479    0.6053    0.6259        76
#         Agent     0.5913    0.4474    0.5094       152
#    Benefactor     0.0000    0.0000    0.0000         9
#   Experiencer     0.4579    0.4224    0.4395       116
#    Instrument     1.0000    0.3750    0.5455        16
#      Location     0.5024    0.6688    0.5738       157
#        Manner     0.7576    0.2941    0.4237        85
#       Measure     0.6702    0.8093    0.7332       236
#        Object     0.7123    0.7034    0.7079       961
#          Time     0.6722    0.7908    0.7267       153
#
#     micro avg     0.6580    0.6563    0.6571      1961
#     macro avg     0.6012    0.5117    0.5285      1961
#  weighted avg     0.6614    0.6563    0.6503      1961
#   samples avg     0.2764    0.2764    0.2764      1961
#
# Hugging Face Transformers Version : 4.15.0
# Hugging Face Tokenizers Version : 0.10.3
# =====================================
# CONFIG_NAME 		=  cv1
# MODEL_PATH 		=  ./wangchan/
# MODEL_NAME 		=  wangchan_cv1
# =========  Hyperparameters  =========
# model_checkpoint 	=  airesearch/wangchanberta-base-att-spm-uncased
# batch_size 		=  4
# =====================================
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset :  DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 1790
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 448
#     })
# })
# Sample  :  ['จิ่งหรีด', 'มัก', 'กัด', 'กิน', 'ต้นกล้า', 'พืช', '_', 'ใบ', 'ของ', 'พืช', '_', 'ส่วน', 'อ่อน', 'เป็น', 'อาหาร']
# Label List :  ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time', 'Verb', 'Z-O']
#
# Tokenization started ...
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/sentencepiece.bpe.model from cache at /home/yoyo/.cache/huggingface/transformers/723940ae01a5606e15164abf96f0ab7c04305fcd51888f3ef83d89950f5d6bfa.0083544422c6efb7b34819bf9daacd1963043dc7f6ac978929e1c28857ac8252
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/tokenizer_config.json from cache at /home/yoyo/.cache/huggingface/transformers/be4bffb4d63c772bad4c531d0cdefc41fe7d056d1954177e9bc7e8975c73a163.13700dc3e64ff4e23d6d8686cf822960ccbe7834db8199e4452261ff8a2df1f4
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv1/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-1436272f74d36a70.arrow
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv1/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-d937146ddecf625b.arrow
# loading configuration file ./wangchan/wangchan_cv1/config.json
# Model config CamembertConfig {
#   "_name_or_path": "./wangchan/wangchan_cv1",
#   "architectures": [
#     "CamembertForTokenClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading weights file ./wangchan/wangchan_cv1/pytorch_model.bin
# Tokenization completed ...
#
#
# Trained Model exists, Load model from ./wangchan/wangchan_cv1.
# All model checkpoint weights were used when initializing CamembertForTokenClassification.
#
# All the weights of CamembertForTokenClassification were initialized from the model checkpoint at ./wangchan/wangchan_cv1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use CamembertForTokenClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# Load Trained Model from ./wangchan/wangchan_cv1 completed ...
# The following columns in the test set  don't have a corresponding argument in `CamembertForTokenClassification.forward` and have been ignored: tokens, role_tags, id.
# ***** Running Prediction *****
#   Num examples = 448
#   Batch size = 4
# Prediction of validation data started ...
#     <div>
#
#       <progress value='112' max='112' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [112/112 00:01]
#     </div>
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Agent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Z-O seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Verb seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Object seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Location seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Manner seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Experiencer seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Time seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Measure seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Instrument seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Benefactor seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Accompanyment seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Prediction of validation data completed ...
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Reusing dataset sem_role_bank (/home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv2/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504)
# {'O': {'precision': 0.3480492813141684, 'recall': 0.45564516129032256, 'f1': 0.3946449359720605, 'number': 744}, 'anner': {'precision': 0.25, 'recall': 0.17391304347826086, 'f1': 0.20512820512820512, 'number': 23}, 'ccompanyment': {'precision': 0.07692307692307693, 'recall': 0.125, 'f1': 0.09523809523809525, 'number': 8}, 'easure': {'precision': 0.23529411764705882, 'recall': 0.375, 'f1': 0.28915662650602403, 'number': 32}, 'enefactor': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 11}, 'erb': {'precision': 0.573076923076923, 'recall': 0.6636971046770601, 'f1': 0.6150670794633643, 'number': 449}, 'gent': {'precision': 0.3877551020408163, 'recall': 0.5757575757575758, 'f1': 0.4634146341463415, 'number': 66}, 'ime': {'precision': 0.26, 'recall': 0.38235294117647056, 'f1': 0.30952380952380953, 'number': 34}, 'nstrument': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 6}, 'ocation': {'precision': 0.24074074074074073, 'recall': 0.35135135135135137, 'f1': 0.2857142857142857, 'number': 74}, 'xperiencer': {'precision': 0.6184971098265896, 'recall': 0.4476987447698745, 'f1': 0.5194174757281553, 'number': 239}, 'overall_precision': 0.41774675972083747, 'overall_recall': 0.4970344009489917, 'overall_f1': 0.4539544962080173, 'overall_accuracy': 0.7047435897435897}
# Align labels to original tokens ...
#
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
#                precision    recall  f1-score   support
#
# Accompanyment     0.8182    0.5745    0.6750        47
#         Agent     0.5070    0.7129    0.5926       101
#    Benefactor     0.0000    0.0000    0.0000         6
#   Experiencer     0.6429    0.4463    0.5268       121
#    Instrument     0.8571    0.1714    0.2857        35
#      Location     0.5911    0.6316    0.6107       190
#        Manner     0.8621    0.3571    0.5051        70
#       Measure     0.5779    0.6312    0.6034       141
#        Object     0.6794    0.7843    0.7281       816
#          Time     0.6000    0.7111    0.6508       135
#
#     micro avg     0.6437    0.6793    0.6610      1662
#     macro avg     0.6136    0.5020    0.5178      1662
#  weighted avg     0.6540    0.6793    0.6521      1662
#   samples avg     0.2729    0.2729    0.2729      1662
#
# Hugging Face Transformers Version : 4.15.0
# Hugging Face Tokenizers Version : 0.10.3
# =====================================
# CONFIG_NAME 		=  cv2
# MODEL_PATH 		=  ./wangchan/
# MODEL_NAME 		=  wangchan_cv2
# =========  Hyperparameters  =========
# model_checkpoint 	=  airesearch/wangchanberta-base-att-spm-uncased
# batch_size 		=  4
# =====================================
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset :  DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 1790
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 448
#     })
# })
# Sample  :  ['ฝึก', 'ให้', 'ลูก', 'กุ้ง', 'กิน', 'อาหาร', 'ไข่ตุ๋น', 'ก่อน']
# Label List :  ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time', 'Verb', 'Z-O']
#
# Tokenization started ...
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/sentencepiece.bpe.model from cache at /home/yoyo/.cache/huggingface/transformers/723940ae01a5606e15164abf96f0ab7c04305fcd51888f3ef83d89950f5d6bfa.0083544422c6efb7b34819bf9daacd1963043dc7f6ac978929e1c28857ac8252
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/tokenizer_config.json from cache at /home/yoyo/.cache/huggingface/transformers/be4bffb4d63c772bad4c531d0cdefc41fe7d056d1954177e9bc7e8975c73a163.13700dc3e64ff4e23d6d8686cf822960ccbe7834db8199e4452261ff8a2df1f4
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv2/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-2eee91c473843116.arrow
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv2/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-ed77ab5e78a028ba.arrow
# loading configuration file ./wangchan/wangchan_cv2/config.json
# Model config CamembertConfig {
#   "_name_or_path": "./wangchan/wangchan_cv2",
#   "architectures": [
#     "CamembertForTokenClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading weights file ./wangchan/wangchan_cv2/pytorch_model.bin
# Tokenization completed ...
#
#
# Trained Model exists, Load model from ./wangchan/wangchan_cv2.
# All model checkpoint weights were used when initializing CamembertForTokenClassification.
#
# All the weights of CamembertForTokenClassification were initialized from the model checkpoint at ./wangchan/wangchan_cv2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use CamembertForTokenClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# Load Trained Model from ./wangchan/wangchan_cv2 completed ...
# The following columns in the test set  don't have a corresponding argument in `CamembertForTokenClassification.forward` and have been ignored: tokens, role_tags, id.
# ***** Running Prediction *****
#   Num examples = 448
#   Batch size = 4
# Prediction of validation data started ...
#     <div>
#
#       <progress value='112' max='112' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [112/112 00:01]
#     </div>
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Z-O seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Agent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Verb seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Object seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Manner seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Benefactor seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Experiencer seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Measure seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Location seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Time seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Instrument seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Accompanyment seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Prediction of validation data completed ...
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Reusing dataset sem_role_bank (/home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv3/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504)
# {'O': {'precision': 0.33950046253469013, 'recall': 0.4610552763819096, 'f1': 0.391049547149707, 'number': 796}, 'anner': {'precision': 0.13333333333333333, 'recall': 0.09523809523809523, 'f1': 0.1111111111111111, 'number': 21}, 'ccompanyment': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 9}, 'easure': {'precision': 0.16901408450704225, 'recall': 0.24489795918367346, 'f1': 0.2, 'number': 49}, 'enefactor': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 13}, 'erb': {'precision': 0.5238095238095238, 'recall': 0.6138392857142857, 'f1': 0.5652620760534429, 'number': 448}, 'gent': {'precision': 0.4263565891472868, 'recall': 0.5670103092783505, 'f1': 0.48672566371681414, 'number': 97}, 'ime': {'precision': 0.13846153846153847, 'recall': 0.2647058823529412, 'f1': 0.18181818181818182, 'number': 34}, 'nstrument': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 11}, 'ocation': {'precision': 0.23958333333333334, 'recall': 0.34328358208955223, 'f1': 0.2822085889570552, 'number': 67}, 'xperiencer': {'precision': 0.5503355704697986, 'recall': 0.43157894736842106, 'f1': 0.4837758112094395, 'number': 190}, 'overall_precision': 0.384794776119403, 'overall_recall': 0.4755043227665706, 'overall_f1': 0.42536736272235115, 'overall_accuracy': 0.6991948083163081}
# Align labels to original tokens ...
#
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
#                precision    recall  f1-score   support
#
# Accompanyment     0.8571    0.5455    0.6667        44
#         Agent     0.6848    0.6494    0.6667       174
#    Benefactor     0.0000    0.0000    0.0000         6
#   Experiencer     0.5556    0.4167    0.4762        96
#    Instrument     1.0000    0.1500    0.2609        40
#      Location     0.5211    0.6735    0.5875       147
#        Manner     0.5217    0.1967    0.2857        61
#       Measure     0.7273    0.6180    0.6682       233
#        Object     0.7140    0.7194    0.7167       916
#          Time     0.5444    0.6765    0.6033       136
#
#     micro avg     0.6702    0.6417    0.6556      1853
#     macro avg     0.6126    0.4646    0.4932      1853
#  weighted avg     0.6779    0.6417    0.6473      1853
#   samples avg     0.2679    0.2679    0.2679      1853
#
# Hugging Face Transformers Version : 4.15.0
# Hugging Face Tokenizers Version : 0.10.3
# =====================================
# CONFIG_NAME 		=  cv3
# MODEL_PATH 		=  ./wangchan/
# MODEL_NAME 		=  wangchan_cv3
# =========  Hyperparameters  =========
# model_checkpoint 	=  airesearch/wangchanberta-base-att-spm-uncased
# batch_size 		=  4
# =====================================
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset :  DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 1791
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 447
#     })
# })
# Sample  :  ['จะ', 'กิน', 'ไร', 'จน', 'มี', 'อายุ', 'ได้', '_', '7', '_', 'วัน']
# Label List :  ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time', 'Verb', 'Z-O']
#
# Tokenization started ...
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/sentencepiece.bpe.model from cache at /home/yoyo/.cache/huggingface/transformers/723940ae01a5606e15164abf96f0ab7c04305fcd51888f3ef83d89950f5d6bfa.0083544422c6efb7b34819bf9daacd1963043dc7f6ac978929e1c28857ac8252
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/tokenizer_config.json from cache at /home/yoyo/.cache/huggingface/transformers/be4bffb4d63c772bad4c531d0cdefc41fe7d056d1954177e9bc7e8975c73a163.13700dc3e64ff4e23d6d8686cf822960ccbe7834db8199e4452261ff8a2df1f4
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv3/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-a70892a994620494.arrow
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/cv3/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-bfd63459821abfd2.arrow
# loading configuration file ./wangchan/wangchan_cv3/config.json
# Model config CamembertConfig {
#   "_name_or_path": "./wangchan/wangchan_cv3",
#   "architectures": [
#     "CamembertForTokenClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading weights file ./wangchan/wangchan_cv3/pytorch_model.bin
# Tokenization completed ...
#
#
# Trained Model exists, Load model from ./wangchan/wangchan_cv3.
# All model checkpoint weights were used when initializing CamembertForTokenClassification.
#
# All the weights of CamembertForTokenClassification were initialized from the model checkpoint at ./wangchan/wangchan_cv3.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use CamembertForTokenClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# Load Trained Model from ./wangchan/wangchan_cv3 completed ...
# The following columns in the test set  don't have a corresponding argument in `CamembertForTokenClassification.forward` and have been ignored: tokens, role_tags, id.
# ***** Running Prediction *****
#   Num examples = 447
#   Batch size = 4
# Prediction of validation data started ...
#     <div>
#
#       <progress value='112' max='112' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [112/112 00:01]
#     </div>
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Z-O seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Verb seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Object seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Manner seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Agent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Measure seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Time seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Location seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Experiencer seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Benefactor seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Instrument seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Accompanyment seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Prediction of validation data completed ...
# ...
# Align labels to original tokens ...
#
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
#                precision    recall  f1-score   support
#
# Accompanyment     0.0000    0.0000    0.0000        24
#         Agent     0.5510    0.3418    0.4219       158
#    Benefactor     0.0000    0.0000    0.0000         9
#   Experiencer     0.5070    0.2748    0.3564       131
#    Instrument     0.0000    0.0000    0.0000        26
#      Location     0.7054    0.3991    0.5098       228
#        Manner     0.0000    0.0000    0.0000        61
#       Measure     0.5683    0.6482    0.6056       199
#        Object     0.6833    0.6206    0.6504       904
#          Time     0.5928    0.6689    0.6286       148
#
#     micro avg     0.6407    0.5138    0.5703      1888
#     macro avg     0.3608    0.2953    0.3173      1888
#  weighted avg     0.6000    0.5138    0.5461      1888
#   samples avg     0.2203    0.2203    0.2203      1888
#
# Hugging Face Transformers Version : 4.15.0
# Hugging Face Tokenizers Version : 0.10.3
# =====================================
# CONFIG_NAME 		=  std
# MODEL_PATH 		=  ./wangchan/
# MODEL_NAME 		=  wangchan_std
# =========  Hyperparameters  =========
# model_checkpoint 	=  airesearch/wangchanberta-base-att-spm-uncased
# batch_size 		=  4
# =====================================
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset :  DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 1790
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'role_tags'],
#         num_rows: 448
#     })
# })
# Sample  :  ['สามารถ', 'ขาย', 'ผลผลิต', 'หมด', 'ก่อน', 'เที่ยง']
# Label List :  ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time', 'Verb', 'Z-O']
#
# Tokenization started ...
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/sentencepiece.bpe.model from cache at /home/yoyo/.cache/huggingface/transformers/723940ae01a5606e15164abf96f0ab7c04305fcd51888f3ef83d89950f5d6bfa.0083544422c6efb7b34819bf9daacd1963043dc7f6ac978929e1c28857ac8252
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/tokenizer_config.json from cache at /home/yoyo/.cache/huggingface/transformers/be4bffb4d63c772bad4c531d0cdefc41fe7d056d1954177e9bc7e8975c73a163.13700dc3e64ff4e23d6d8686cf822960ccbe7834db8199e4452261ff8a2df1f4
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading configuration file https://huggingface.co/airesearch/wangchanberta-base-att-spm-uncased/resolve/main/config.json from cache at /home/yoyo/.cache/huggingface/transformers/616a9e2dfc52e9d019b75d219ed800a27158ed299bd4fad91363110fe93dfce1.27c4f6581fbedf3d12e9fae96d4fbb8bc3064cd88ae545414e7cffc7c5bbc52f
# Model config CamembertConfig {
#   "_name_or_path": "airesearch/wangchanberta-base-att-spm-uncased",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/std/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-62a693c7d66a715a.arrow
# Loading cached processed dataset at /home/yoyo/.cache/huggingface/datasets/sem_role_bank/std/1.0.0/0c634fc12d7a4053678206c059870924992d934fd51018d1ac4d8227d3472504/cache-360879bb996e43b2.arrow
# loading configuration file ./wangchan/wangchan_std/config.json
# Model config CamembertConfig {
#   "_name_or_path": "./wangchan/wangchan_std",
#   "architectures": [
#     "CamembertForTokenClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "camembert",
#   "num_attention_head": 12,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.15.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 25005
# }
#
# loading weights file ./wangchan/wangchan_std/pytorch_model.bin
# Tokenization completed ...
#
#
# Trained Model exists, Load model from ./wangchan/wangchan_std.
# All model checkpoint weights were used when initializing CamembertForTokenClassification.
#
# All the weights of CamembertForTokenClassification were initialized from the model checkpoint at ./wangchan/wangchan_std.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use CamembertForTokenClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# Load Trained Model from ./wangchan/wangchan_std completed ...
# The following columns in the test set  don't have a corresponding argument in `CamembertForTokenClassification.forward` and have been ignored: tokens, role_tags, id.
# ***** Running Prediction *****
#   Num examples = 448
#   Batch size = 4
# Prediction of validation data started ...
#     <div>
#
#       <progress value='112' max='112' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [112/112 00:01]
#     </div>
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Z-O seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Verb seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Object seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Manner seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Time seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Agent seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Measure seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Location seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Experiencer seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Accompanyment seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Benefactor seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: Instrument seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Prediction of validation data completed ...
#
# {'O': {'precision': 0.31491228070175437, 'recall': 0.43409915356711004, 'f1': 0.36502287747839346, 'number': 827}, 'anner': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 25}, 'ccompanyment': {'precision': 0.03333333333333333, 'recall': 0.1111111111111111, 'f1': 0.05128205128205128, 'number': 9}, 'easure': {'precision': 0.09174311926605505, 'recall': 0.20833333333333334, 'f1': 0.12738853503184713, 'number': 48}, 'enefactor': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 16}, 'erb': {'precision': 0.5681818181818182, 'recall': 0.6651884700665188, 'f1': 0.6128702757916241, 'number': 451}, 'gent': {'precision': 0.3, 'recall': 0.46153846153846156, 'f1': 0.3636363636363637, 'number': 78}, 'ime': {'precision': 0.10714285714285714, 'recall': 0.2, 'f1': 0.13953488372093023, 'number': 45}, 'nstrument': {'precision': 0.3333333333333333, 'recall': 0.125, 'f1': 0.18181818181818182, 'number': 8}, 'ocation': {'precision': 0.2524271844660194, 'recall': 0.35135135135135137, 'f1': 0.29378531073446323, 'number': 74}, 'xperiencer': {'precision': 0.5123456790123457, 'recall': 0.3333333333333333, 'f1': 0.40389294403892945, 'number': 249}, 'overall_precision': 0.36041939711664484, 'overall_recall': 0.45081967213114754, 'overall_f1': 0.4005826656955571, 'overall_accuracy': 0.6883042933606651}
# Align labels to original tokens ...
#
# ['Accompanyment', 'Agent', 'Benefactor', 'Experiencer', 'Instrument', 'Location', 'Manner', 'Measure', 'Object', 'Time']
#                precision    recall  f1-score   support
#
# Accompanyment     0.6000    0.3947    0.4762        76
#         Agent     0.5106    0.4737    0.4915       152
#    Benefactor     0.0000    0.0000    0.0000         9
#   Experiencer     0.4744    0.3190    0.3814       116
#    Instrument     0.8571    0.3750    0.5217        16
#      Location     0.5220    0.6051    0.5605       157
#        Manner     0.8947    0.2000    0.3269        85
#       Measure     0.6735    0.6992    0.6861       236
#        Object     0.6952    0.7097    0.7024       961
#          Time     0.5693    0.7516    0.6479       153
#
#     micro avg     0.6399    0.6216    0.6306      1961
#     macro avg     0.5797    0.4528    0.4795      1961
#  weighted avg     0.6446    0.6216    0.6197      1961
#   samples avg     0.2618    0.2618    0.2618      1961
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/yoyo/anaconda3/envs/bert/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %run sem_role_wangchan.py --config_name=$CONFIG_NAME --model_path=$MODEL_PATH --model_name=$MODEL_NAME
